# %%
class bcolors:
    OK = '\033[92m' #GREEN
    WARNING = '\033[93m' #YELLOW
    FAIL = '\033[91m' #RED
    RESET = '\033[0m' #RESET COLOR

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, WeightedRandomSampler, Sampler, SubsetRandomSampler
import numpy as np
import pandas as pd
import torchvision
from torchvision import datasets, models
import matplotlib.pyplot as plt
import time
import os
import copy

import albumentations as A
from albumentations.pytorch import ToTensorV2

from math import ceil
import seaborn as sn

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, classification_report

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f'{bcolors.OK}{device}{bcolors.RESET}')
# Out:
# cuda:0

# %%
# set the attempt number in attempt
# # set the model name in model
# set the model version in version

hyper_parameter = {
    "attempt": 0.8,
    "model": 'efficientnet',
    "version": 'b1',
    "learning_rate": 0.1,
    "batch_size": 10,
    "num_workers": 2,
    "no_epochs": 100,
    "image_size": 224, 
    "in_channels": 3, 
    "num_classes": 8,
    "load_model": True
}

# %%
# set data directory
data_dir = 'D:\sl\images'
sets = ['train', 'test']
# to use checkpoint saving create a directory named "checkpoint" and a sub directory in the name of the model
checkpoint_path = f'./checkpoints/{hyper_parameter["model"]}/{hyper_parameter["model"]}{hyper_parameter["version"]}-{hyper_parameter["attempt"]}'


print(f'{bcolors.OK}Enviroment setup complete 😊🐼!{bcolors.RESET}')
# Out:
# Enviroment setup complete 😊🐼!

# %%
classes = ['AK', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'SCC', 'VASC']
image_frequency = pd.DataFrame(columns=sets, index=classes)
for dataset in iter(sets):
    for classname in iter(classes):
        image_frequency[dataset][classname] = len(os.listdir(os.path.join(data_dir, dataset, classname)))
image_frequency.index = image_frequency.index.rename('classes')

print(image_frequency.to_markdown())
print(image_frequency.sum(axis=0))
# Out:
# | classes   |   train |   test |
# |:----------|--------:|-------:|
# | AK        |     689 |    178 |
# | BCC       |    2669 |    654 |
# | BKL       |    2077 |    547 |
# | DF        |     180 |     59 |
# | MEL       |    3608 |    914 |
# | NV        |   10330 |   2545 |
# | SCC       |     509 |    119 |
# | VASC      |     203 |     50 |
# train    20265
# test      5066
# dtype: object

# %%
class Transforms:
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, img, *args, **kwargs):
        return self.transforms(image=np.array(img))['image']

# %%
# set the mean and std based on the model documentation
# for efficient net bo - pytorch documentation
mean=[0.485, 0.456, 0.406]
std=[0.229, 0.224, 0.225]
# hyper_parameter['image_size']=32

data_transforms = {
    'train': A.Compose([A.Resize(hyper_parameter['image_size'] , hyper_parameter['image_size']), A.Normalize(mean, std), ToTensorV2()]),
    'test': A.Compose([A.Resize(hyper_parameter['image_size'] , hyper_parameter['image_size']), A.Normalize(mean, std), ToTensorV2()])
}

# %%
# create dataset and dataloader
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), transform =Transforms(transforms=data_transforms[x])) for x in sets}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=hyper_parameter['batch_size'], shuffle=True) for x in sets}

dataset_sizes = {x: len(image_datasets[x]) for x in sets}
class_names = image_datasets['train'].classes

print('train: {} test: {}'.format(dataset_sizes['train'], dataset_sizes['test']))
print(class_names)
# Out:
# train: 20265 test: 5066
# ['AK', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'SCC', 'VASC']

# %%
# Train Loader - count the frequency of images in every iteration
num_ak, num_bcc, num_bkl, num_df, num_mel, num_nv, num_scc, num_vasc = 0,0,0,0,0,0,0,0
for data, labels in dataloaders['train']:
    num_ak += torch.sum(labels==0)
    num_bcc += torch.sum(labels==1)
    num_bkl += torch.sum(labels==2)
    num_df += torch.sum(labels==3)
    num_mel += torch.sum(labels==4)
    num_nv += torch.sum(labels==5)
    num_scc += torch.sum(labels==6)
    num_vasc += torch.sum(labels==7)
print(f'AK: {num_ak}, BCC: {num_bcc}, BKL: {num_bkl}, DF: {num_df}, MEL: {num_mel}, NV: {num_nv}, SCC: {num_scc}, VASC: {num_vasc}')
# Out:
# AK: 689, BCC: 2669, BKL: 2077, DF: 180, MEL: 3608, NV: 10330, SCC: 509, VASC: 203

# %%
# Test Loader - count the frequency of images in every iteration
num_ak, num_bcc, num_bkl, num_df, num_mel, num_nv, num_scc, num_vasc = 0,0,0,0,0,0,0,0
for data, labels in dataloaders['test']:
    num_ak += torch.sum(labels==0)
    num_bcc += torch.sum(labels==1)
    num_bkl += torch.sum(labels==2)
    num_df += torch.sum(labels==3)
    num_mel += torch.sum(labels==4)
    num_nv += torch.sum(labels==5)
    num_scc += torch.sum(labels==6)
    num_vasc += torch.sum(labels==7)
print(f'AK: {num_ak}, BCC: {num_bcc}, BKL: {num_bkl}, DF: {num_df}, MEL: {num_mel}, NV: {num_nv}, SCC: {num_scc}, VASC: {num_vasc}')
# Out:
# AK: 178, BCC: 654, BKL: 547, DF: 59, MEL: 914, NV: 2545, SCC: 119, VASC: 50

# %%
# Helper function for inline image display
def imshow(inp, title):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    plt.title(title)
    plt.show()

images, classes = next(iter(dataloaders['train']))

# Create a grid from the images and show them
img_grid = torchvision.utils.make_grid(images)
imshow(img_grid, title=[class_names[x] for x in classes])

# %%
base_model = [
    # expand_ratio, channels, repeats, stride, kernel_size
    [1, 16, 1, 1, 3],
    [6, 24, 2, 2, 3],
    [6, 40, 2, 2, 5],
    [6, 80, 3, 2, 3],
    [6, 112, 3, 1, 5],
    [6, 192, 4, 2, 5],
    [6, 320, 1, 1, 3],
]

phi_values = {
    # tuple of: (phi_value, resolution, drop_rate)
    "b0": (0, 224, 0.2),  # alpha, beta, gamma, depth = alpha ** phi
    "b1": (0.5, 240, 0.2),
    "b2": (1, 260, 0.3),
    "b3": (2, 300, 0.3),
    "b4": (3, 380, 0.4),
    "b5": (4, 456, 0.4),
    "b6": (5, 528, 0.5),
    "b7": (6, 600, 0.5),
}

class CNNBlock(nn.Module):
    def __init__(
            self, in_channels, out_channels, kernel_size, stride, padding, groups=1
    ):
        super(CNNBlock, self).__init__()
        self.cnn = nn.Conv2d(
            in_channels,
            out_channels,
            kernel_size,
            stride,
            padding,
            groups=groups,
            bias=False,
        )
        self.bn = nn.BatchNorm2d(out_channels)
        self.silu = nn.SiLU() # SiLU <-> Swish

    def forward(self, x):
        return self.silu(self.bn(self.cnn(x)))

class SqueezeExcitation(nn.Module):
    def __init__(self, in_channels, reduced_dim):
        super(SqueezeExcitation, self).__init__()
        self.se = nn.Sequential(
            nn.AdaptiveAvgPool2d(1), # C x H x W -> C x 1 x 1
            nn.Conv2d(in_channels, reduced_dim, 1),
            nn.SiLU(),
            nn.Conv2d(reduced_dim, in_channels, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return x * self.se(x)

class InvertedResidualBlock(nn.Module):
    def __init__(
            self,
            in_channels,
            out_channels,
            kernel_size,
            stride,
            padding,
            expand_ratio,
            reduction=4, # squeeze excitation
            survival_prob=0.8, # for stochastic depth
    ):
        super(InvertedResidualBlock, self).__init__()
        self.survival_prob = 0.8
        self.use_residual = in_channels == out_channels and stride == 1
        hidden_dim = in_channels * expand_ratio
        self.expand = in_channels != hidden_dim
        reduced_dim = int(in_channels / reduction)

        if self.expand:
            self.expand_conv = CNNBlock(
                in_channels, hidden_dim, kernel_size=3, stride=1, padding=1,
            )

        self.conv = nn.Sequential(
            CNNBlock(
                hidden_dim, hidden_dim, kernel_size, stride, padding, groups=hidden_dim,
            ),
            SqueezeExcitation(hidden_dim, reduced_dim),
            nn.Conv2d(hidden_dim, out_channels, 1, bias=False),
            nn.BatchNorm2d(out_channels),
        )

    def stochastic_depth(self, x):
        if not self.training:
            return x

        binary_tensor = torch.rand(x.shape[0], 1, 1, 1, device=x.device) < self.survival_prob
        return torch.div(x, self.survival_prob) * binary_tensor

    def forward(self, inputs):
        x = self.expand_conv(inputs) if self.expand else inputs

        if self.use_residual:
            return self.stochastic_depth(self.conv(x)) + inputs
        else:
            return self.conv(x)

# %%
class EfficientNet(nn.Module):
    def __init__(self, version, num_classes):
        super(EfficientNet, self).__init__()
        width_factor, depth_factor, dropout_rate = self.calculate_factors(version)
        last_channels = ceil(1280 * width_factor)
        self.pool = nn.AdaptiveAvgPool2d(1)
        self.features = self.create_features(width_factor, depth_factor, last_channels)
        self.classifier = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(last_channels, num_classes),
        )

    def calculate_factors(self, version, alpha=1.2, beta=1.1):
        phi, res, drop_rate = phi_values[version]
        depth_factor = alpha ** phi
        width_factor = beta ** phi
        return width_factor, depth_factor, drop_rate

    def create_features(self, width_factor, depth_factor, last_channels):
        channels = int(32 * width_factor)
        features = [CNNBlock(3, channels, 3, stride=2, padding=1)]
        in_channels = channels

        for expand_ratio, channels, repeats, stride, kernel_size in base_model:
            out_channels = 4*ceil(int(channels*width_factor) / 4)
            layers_repeats = ceil(repeats * depth_factor)

            for layer in range(layers_repeats):
                features.append(
                    InvertedResidualBlock(
                        in_channels,
                        out_channels,
                        expand_ratio=expand_ratio,
                        stride = stride if layer == 0 else 1,
                        kernel_size=kernel_size,
                        padding=kernel_size//2, # if k=1:pad=0, k=3:pad=1, k=5:pad=2
                    )
                )
                in_channels = out_channels

        features.append(
            CNNBlock(in_channels, last_channels, kernel_size=1, stride=1, padding=0)
        )

        return nn.Sequential(*features)

    def forward(self, x):
        x = self.pool(self.features(x))
        return self.classifier(x.view(x.shape[0], -1))

# %%
# class Identity(nn.Module):
#     def __init__(self):
#         super(Identity, self).__init__()
    
#     def forward(self, x):
#         return x

# %%
version = hyper_parameter['version']
model = EfficientNet(version=version, num_classes=hyper_parameter['num_classes'])

# %%
# define model and optimizers
model.to(device)

next(model.parameters()).device

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = hyper_parameter['learning_rate'])

# scheduler
step_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)

# %%
# view model architecture
# print(model.parameters)

# %%
train_results = {
    'accuracy': np.zeros(hyper_parameter['no_epochs'], dtype=float),
    'f1_score': np.zeros(hyper_parameter['no_epochs'], dtype=float),
    'loss': np.zeros(hyper_parameter['no_epochs'], dtype=float),
    'cf_matrix': np.zeros((hyper_parameter['num_classes'], hyper_parameter['num_classes']), dtype=float)
}

test_results = {
    'accuracy': np.zeros(hyper_parameter['no_epochs'], dtype=float),
    'f1_score': np.zeros(hyper_parameter['no_epochs'], dtype=float),
    'loss': np.zeros(hyper_parameter['no_epochs'], dtype=float),
    'cf_matrix': np.zeros((hyper_parameter['num_classes'], hyper_parameter['num_classes']), dtype=float)
}

results = {
    'train': train_results,
    'test': test_results
}

# %%
save_path = f'{checkpoint_path}.pth.tar'
print(f'Save Path: {save_path}')

def save_checkpoint(state, epoch, filename = save_path):
    print(f'=> Checkpoint at {epoch + 1} saved!')
    print(f'Saved at: {save_path}')
    torch.save(state, filename)

def load_checkpoint(checkpoint):
    print(f'=> Loading Checkpoint')
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
# Out:
# Save Path: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar

# %%
def train_model(model, cirterion, optimizer, scheduler, num_epochs = 1):
  since = time.time()

  best_model_wts = copy.deepcopy(model.state_dict())
  best_acc = 0.0
  best_f1_scr = 0.0

  for epoch in range(num_epochs):
    print('Epoch {}/{}'.format(epoch + 1, num_epochs))
    print('-' * 15)

    for phase in ['train', 'test']:
      if phase =='train':
        model.train()
      else:
        model.eval()
      
      running_loss = 0.0
      running_corrects = 0.0

      real_targets = []
      predicted_targets = []

      # Iterate over data.
      for inputs, labels in dataloaders[phase]:
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward
        # track history only if train
        with torch.set_grad_enabled(phase == 'train'):
          outputs = model(inputs)
          _, preds = torch.max(outputs, 1)
          
          real_targets.extend(labels.detach().cpu().numpy())
          predicted_targets.extend(preds.detach().cpu().numpy())

          loss = cirterion(outputs, labels)

          # backward + optimize only if in train
          if phase == 'train':
            loss.backward()
            optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
      ### EPOCH Train & Test ###
      if phase == 'train':
        scheduler.step()

      sk_f1 = f1_score(predicted_targets, real_targets, average='micro')
      epoch_cf_matrix = confusion_matrix(real_targets, predicted_targets)

      epoch_loss = running_loss / dataset_sizes[phase]
      epoch_acc = running_corrects / dataset_sizes[phase]

      results[phase]['accuracy'][epoch] = epoch_acc
      results[phase]['loss'][epoch] = epoch_loss
      results[phase]['f1_score'][epoch] = sk_f1
      results[phase]['cf_matrix'] += epoch_cf_matrix

      # printing epoch resutlts
      if (epoch + 1) % 2 == 0:
        print(f'{phase} Loss: {epoch_loss:.4f}, Acc: {epoch_acc:.4f}')

      epoch_time = time.time() - since
      print(f'Epoch time: {epoch_time // 60:.0f}m {epoch_time %  60:.0f}s')

      if phase == 'test' and epoch_acc > best_acc:
        best_acc = epoch_acc
        best_model_wts = copy.deepcopy(model.state_dict())
      
      if phase == 'test' and sk_f1 > best_f1_scr:
        best_f1_scr = sk_f1
    
    if (epoch + 1) % 2 == 0:
      checkpoint = {
        'state_dict': model.state_dict(),
        'optimizer': optimizer.state_dict()
      }
      save_checkpoint(checkpoint, epoch)

    print()
    ######################################################

  # training Complete
  # printing time require to train model
  time_elapsed = time.time() - since
  print(f'Training complete in {time_elapsed // 60:.0f}m { time_elapsed % 60:.0f}s')

  t = time.localtime()
  current_time = time.strftime("%H:%M", t)
  print(f'Trainig completed at {current_time}')
  print(f'Best val Acc: {best_acc:4f}')
  print(f'Best sk F1 : {best_f1_scr:4f}')

  for phase in ['train', 'test']:
    df_cm = pd.DataFrame(results[phase]['cf_matrix'], index = class_names, columns = class_names)
    plt.figure(figsize = (12,7))
    sn.heatmap(df_cm, annot=True)
    plt.tight_layout()
  plt.savefig(f'{checkpoint_path}_cf_matrix.svg')
  plt.show()

  for phase in ['train', 'test']:
    plt.plot(results[phase]['accuracy'], label='{} accuracy'.format(phase))
    plt.title(f'{hyper_parameter["model"]} {hyper_parameter["version"]} learning rate: {hyper_parameter["learning_rate"]} epoch: {hyper_parameter["no_epochs"]}')
    plt.legend(bbox_to_anchor = (1.45, 1), loc='upper right')
    plt.tight_layout()
  plt.savefig(f'{checkpoint_path}_accuracy.svg')
  plt.show()

  # for phase in ['train', 'test']:
  #   plt.plot(results[phase]['f1_score'], label='{} f1 score'.format(phase))
  #   plt.legend(bbox_to_anchor = (1.45, 1), loc='upper right')
  #   plt.tight_layout()
  # plt.savefig(f'{checkpoint_path}_f1_score.svg')
  # plt.show()
  
  for phase in ['train', 'test']:
    plt.plot(results[phase]['loss'], label='{} loss'.format(phase))
    plt.title(f'{hyper_parameter["model"]} {hyper_parameter["version"]} learning rate: {hyper_parameter["learning_rate"]} epoch: {hyper_parameter["no_epochs"]}')
    plt.legend(bbox_to_anchor = (1.45, 1), loc='upper right')
    plt.tight_layout()
  plt.savefig(f'{checkpoint_path}_loss.svg')
  plt.show()

  # load best model weights
  model.load_state_dict(best_model_wts)
  return model

# %%
# load_path = f'{checkpoint_path}.pth.tar'
# if hyper_parameter['load_model']:
#     load_checkpoint(torch.load(load_path))

# %%
# weights = dict()
# for name, para in model.named_parameters():
#     weights[name] = para
# print(weights)

# %%
model = train_model(model, criterion, optimizer, step_lr_scheduler, num_epochs=hyper_parameter['no_epochs'])
# Out:
# Epoch 1/100
# ---------------
# Epoch time: 52m 31s
# Epoch time: 57m 25s
#
# Epoch 2/100
# ---------------
# train Loss: 2.1735, Acc: 0.4425
# Epoch time: 94m 20s
# test Loss: 1.4045, Acc: 0.5308
# Epoch time: 99m 47s
# => Checkpoint at 2 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 3/100
# ---------------
# Epoch time: 134m 60s
# Epoch time: 138m 41s
#
# Epoch 4/100
# ---------------
# train Loss: 1.8214, Acc: 0.4599
# Epoch time: 163m 2s
# test Loss: 1.4697, Acc: 0.5318
# Epoch time: 167m 11s
# => Checkpoint at 4 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 5/100
# ---------------
# Epoch time: 191m 46s
# Epoch time: 195m 35s
#
# Epoch 6/100
# ---------------
# train Loss: 1.6489, Acc: 0.4930
# Epoch time: 221m 5s
# test Loss: 1.3278, Acc: 0.5509
# Epoch time: 224m 58s
# => Checkpoint at 6 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 7/100
# ---------------
# Epoch time: 249m 45s
# Epoch time: 253m 38s
#
# Epoch 8/100
# ---------------
# train Loss: 1.3298, Acc: 0.5403
# Epoch time: 278m 4s
# test Loss: 1.2523, Acc: 0.5570
# Epoch time: 282m 7s
# => Checkpoint at 8 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 9/100
# ---------------
# Epoch time: 307m 6s
# Epoch time: 310m 43s
#
# Epoch 10/100
# ---------------
# train Loss: 1.2617, Acc: 0.5601
# Epoch time: 336m 43s
# test Loss: 1.2064, Acc: 0.5681
# Epoch time: 341m 11s
# => Checkpoint at 10 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 11/100
# ---------------
# Epoch time: 366m 35s
# Epoch time: 370m 15s
#
# Epoch 12/100
# ---------------
# train Loss: 1.1756, Acc: 0.5879
# Epoch time: 394m 9s
# test Loss: 1.1288, Acc: 0.6076
# Epoch time: 397m 47s
# => Checkpoint at 12 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 13/100
# ---------------
# Epoch time: 421m 32s
# Epoch time: 425m 10s
#
# Epoch 14/100
# ---------------
# train Loss: 1.1575, Acc: 0.5966
# Epoch time: 448m 45s
# test Loss: 545157070.5788, Acc: 0.5995
# Epoch time: 452m 24s
# => Checkpoint at 14 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 15/100
# ---------------
# Epoch time: 476m 6s
# Epoch time: 479m 45s
#
# Epoch 16/100
# ---------------
# train Loss: 1.1410, Acc: 0.5984
# Epoch time: 503m 58s
# test Loss: 1.1700, Acc: 0.5823
# Epoch time: 507m 37s
# => Checkpoint at 16 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 17/100
# ---------------
# Epoch time: 531m 17s
# Epoch time: 534m 57s
#
# Epoch 18/100
# ---------------
# train Loss: 1.1160, Acc: 0.6079
# Epoch time: 558m 31s
# test Loss: 1.1184, Acc: 0.5993
# Epoch time: 562m 10s
# => Checkpoint at 18 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 19/100
# ---------------
# Epoch time: 585m 52s
# Epoch time: 589m 31s
#
# Epoch 20/100
# ---------------
# train Loss: 1.1064, Acc: 0.6087
# Epoch time: 613m 5s
# test Loss: 1.0641, Acc: 0.6188
# Epoch time: 616m 46s
# => Checkpoint at 20 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 21/100
# ---------------
# Epoch time: 640m 29s
# Epoch time: 644m 8s
#
# Epoch 22/100
# ---------------
# train Loss: 1.0922, Acc: 0.6151
# Epoch time: 667m 44s
# test Loss: 22570.3996, Acc: 0.6101
# Epoch time: 671m 22s
# => Checkpoint at 22 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 23/100
# ---------------
# Epoch time: 695m 49s
# Epoch time: 699m 29s
#
# Epoch 24/100
# ---------------
# train Loss: 1.0849, Acc: 0.6163
# Epoch time: 723m 7s
# test Loss: 2912565594531237.5000, Acc: 0.6088
# Epoch time: 726m 45s
# => Checkpoint at 24 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 25/100
# ---------------
# Epoch time: 750m 34s
# Epoch time: 754m 12s
#
# Epoch 26/100
# ---------------
# train Loss: 1.0701, Acc: 0.6228
# Epoch time: 777m 50s
# test Loss: 1.0589, Acc: 0.6267
# Epoch time: 781m 28s
# => Checkpoint at 26 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 27/100
# ---------------
# Epoch time: 805m 41s
# Epoch time: 809m 19s
#
# Epoch 28/100
# ---------------
# train Loss: 1.0567, Acc: 0.6266
# Epoch time: 832m 47s
# test Loss: 10914068266443110.0000, Acc: 0.6163
# Epoch time: 836m 23s
# => Checkpoint at 28 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 29/100
# ---------------
# Epoch time: 859m 53s
# Epoch time: 863m 31s
#
# Epoch 30/100
# ---------------
# train Loss: 1.0478, Acc: 0.6312
# Epoch time: 887m 7s
# test Loss: 20615861.2867, Acc: 0.6165
# Epoch time: 890m 46s
# => Checkpoint at 30 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 31/100
# ---------------
# Epoch time: 914m 19s
# Epoch time: 917m 59s
#
# Epoch 32/100
# ---------------
# train Loss: 0.9609, Acc: 0.6570
# Epoch time: 942m 8s
# test Loss: 1032626879691960192.0000, Acc: 0.6344
# Epoch time: 945m 45s
# => Checkpoint at 32 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 33/100
# ---------------
# Epoch time: 969m 16s
# Epoch time: 972m 54s
#
# Epoch 34/100
# ---------------
# train Loss: 0.9474, Acc: 0.6628
# Epoch time: 996m 33s
# test Loss: 2163666.8385, Acc: 0.6326
# Epoch time: 1000m 11s
# => Checkpoint at 34 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 35/100
# ---------------
# Epoch time: 1023m 43s
# Epoch time: 1027m 18s
#
# Epoch 36/100
# ---------------
# train Loss: 0.9361, Acc: 0.6657
# Epoch time: 1050m 40s
# test Loss: 1.0264, Acc: 0.6305
# Epoch time: 1054m 14s
# => Checkpoint at 36 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 37/100
# ---------------
# Epoch time: 1073m 4s
# Epoch time: 1075m 37s
#
# Epoch 38/100
# ---------------
# train Loss: 0.9276, Acc: 0.6660
# Epoch time: 1093m 54s
# test Loss: 1641866477787140864.0000, Acc: 0.6299
# Epoch time: 1096m 27s
# => Checkpoint at 38 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 39/100
# ---------------
# Epoch time: 1114m 45s
# Epoch time: 1117m 18s
#
# Epoch 40/100
# ---------------
# train Loss: 0.9128, Acc: 0.6728
# Epoch time: 1135m 34s
# test Loss: 42848822784445276160.0000, Acc: 0.6380
# Epoch time: 1138m 8s
# => Checkpoint at 40 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 41/100
# ---------------
# Epoch time: 1156m 25s
# Epoch time: 1158m 58s
#
# Epoch 42/100
# ---------------
# train Loss: 0.9074, Acc: 0.6726
# Epoch time: 1177m 19s
# test Loss: 243476296568281.3438, Acc: 0.6366
# Epoch time: 1179m 52s
# => Checkpoint at 42 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 43/100
# ---------------
# Epoch time: 1198m 26s
# Epoch time: 1201m 9s
#
# Epoch 44/100
# ---------------
# train Loss: 0.9031, Acc: 0.6770
# Epoch time: 1219m 44s
# test Loss: nan, Acc: 0.6344
# Epoch time: 1222m 21s
# => Checkpoint at 44 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 45/100
# ---------------
# Epoch time: 1240m 44s
# Epoch time: 1243m 18s
#
# Epoch 46/100
# ---------------
# train Loss: 0.8924, Acc: 0.6805
# Epoch time: 1261m 35s
# test Loss: nan, Acc: 0.6366
# Epoch time: 1264m 9s
# => Checkpoint at 46 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 47/100
# ---------------
# Epoch time: 1283m 40s
# Epoch time: 1286m 26s
#
# Epoch 48/100
# ---------------
# train Loss: 0.8822, Acc: 0.6840
# Epoch time: 1305m 31s
# test Loss: nan, Acc: 0.6356
# Epoch time: 1308m 11s
# => Checkpoint at 48 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 49/100
# ---------------
# Epoch time: 1326m 33s
# Epoch time: 1329m 6s
#
# Epoch 50/100
# ---------------
# train Loss: 0.8680, Acc: 0.6912
# Epoch time: 1347m 24s
# test Loss: 24678461465.2937, Acc: 0.6342
# Epoch time: 1349m 58s
# => Checkpoint at 50 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 51/100
# ---------------
# Epoch time: 1368m 17s
# Epoch time: 1370m 51s
#
# Epoch 52/100
# ---------------
# train Loss: 0.8653, Acc: 0.6883
# Epoch time: 1389m 8s
# test Loss: nan, Acc: 0.6323
# Epoch time: 1391m 42s
# => Checkpoint at 52 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 53/100
# ---------------
# Epoch time: 1410m 0s
# Epoch time: 1412m 33s
#
# Epoch 54/100
# ---------------
# train Loss: 0.8522, Acc: 0.6943
# Epoch time: 1430m 51s
# test Loss: nan, Acc: 0.6295
# Epoch time: 1433m 25s
# => Checkpoint at 54 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 55/100
# ---------------
# Epoch time: 1451m 44s
# Epoch time: 1454m 18s
#
# Epoch 56/100
# ---------------
# train Loss: 0.8452, Acc: 0.6964
# Epoch time: 1472m 35s
# test Loss: nan, Acc: 0.6297
# Epoch time: 1475m 9s
# => Checkpoint at 56 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 57/100
# ---------------
# Epoch time: 1493m 27s
# Epoch time: 1496m 1s
#
# Epoch 58/100
# ---------------
# train Loss: 0.8352, Acc: 0.6992
# Epoch time: 1515m 39s
# test Loss: nan, Acc: 0.6332
# Epoch time: 1518m 18s
# => Checkpoint at 58 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 59/100
# ---------------
# Epoch time: 1537m 30s
# Epoch time: 1540m 14s
#
# Epoch 60/100
# ---------------
# train Loss: 0.8294, Acc: 0.7008
# Epoch time: 1559m 11s
# test Loss: nan, Acc: 0.6287
# Epoch time: 1561m 45s
# => Checkpoint at 60 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 61/100
# ---------------
# Epoch time: 1580m 4s
# Epoch time: 1582m 39s
#
# Epoch 62/100
# ---------------
# train Loss: 0.8024, Acc: 0.7094
# Epoch time: 1601m 6s
# test Loss: 3654843767761760765584867328.0000, Acc: 0.6305
# Epoch time: 1603m 46s
# => Checkpoint at 62 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 63/100
# ---------------
# Epoch time: 1622m 42s
# Epoch time: 1625m 24s
#
# Epoch 64/100
# ---------------
# train Loss: 0.8005, Acc: 0.7117
# Epoch time: 1644m 57s
# test Loss: nan, Acc: 0.6269
# Epoch time: 1647m 43s
# => Checkpoint at 64 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 65/100
# ---------------
# Epoch time: 1667m 23s
# Epoch time: 1670m 12s
#
# Epoch 66/100
# ---------------
# train Loss: 0.7925, Acc: 0.7120
# Epoch time: 1689m 57s
# test Loss: 2447616127093331607869718528.0000, Acc: 0.6257
# Epoch time: 1692m 30s
# => Checkpoint at 66 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 67/100
# ---------------
# Epoch time: 1711m 27s
# Epoch time: 1714m 11s
#
# Epoch 68/100
# ---------------
# train Loss: 0.7884, Acc: 0.7128
# Epoch time: 1732m 40s
# test Loss: nan, Acc: 0.6244
# Epoch time: 1735m 14s
# => Checkpoint at 68 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 69/100
# ---------------
# Epoch time: 1753m 39s
# Epoch time: 1756m 13s
#
# Epoch 70/100
# ---------------
# train Loss: 0.7898, Acc: 0.7135
# Epoch time: 1774m 38s
# test Loss: nan, Acc: 0.6279
# Epoch time: 1777m 12s
# => Checkpoint at 70 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 71/100
# ---------------
# Epoch time: 1795m 37s
# Epoch time: 1798m 11s
#
# Epoch 72/100
# ---------------
# train Loss: 0.7872, Acc: 0.7153
# Epoch time: 1816m 35s
# test Loss: nan, Acc: 0.6297
# Epoch time: 1819m 9s
# => Checkpoint at 72 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 73/100
# ---------------
# Epoch time: 1837m 34s
# Epoch time: 1840m 7s
#
# Epoch 74/100
# ---------------
# train Loss: 0.7809, Acc: 0.7154
# Epoch time: 1858m 31s
# test Loss: nan, Acc: 0.6303
# Epoch time: 1861m 5s
# => Checkpoint at 74 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 75/100
# ---------------
# Epoch time: 1879m 30s
# Epoch time: 1882m 4s
#
# Epoch 76/100
# ---------------
# train Loss: 0.7813, Acc: 0.7182
# Epoch time: 1900m 28s
# test Loss: nan, Acc: 0.6176
# Epoch time: 1903m 2s
# => Checkpoint at 76 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 77/100
# ---------------
# Epoch time: 1921m 26s
# Epoch time: 1924m 1s
#
# Epoch 78/100
# ---------------
# train Loss: 0.7698, Acc: 0.7218
# Epoch time: 1942m 25s
# test Loss: nan, Acc: 0.6313
# Epoch time: 1944m 59s
# => Checkpoint at 78 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 79/100
# ---------------
# Epoch time: 1963m 23s
# Epoch time: 1965m 57s
#
# Epoch 80/100
# ---------------
# train Loss: 0.7724, Acc: 0.7204
# Epoch time: 1984m 21s
# test Loss: nan, Acc: 0.6269
# Epoch time: 1986m 55s
# => Checkpoint at 80 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 81/100
# ---------------
# Epoch time: 2005m 19s
# Epoch time: 2007m 54s
#
# Epoch 82/100
# ---------------
# train Loss: 0.7772, Acc: 0.7211
# Epoch time: 2026m 17s
# test Loss: nan, Acc: 0.6303
# Epoch time: 2028m 51s
# => Checkpoint at 82 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 83/100
# ---------------
# Epoch time: 2047m 16s
# Epoch time: 2049m 49s
#
# Epoch 84/100
# ---------------
# train Loss: 0.7729, Acc: 0.7213
# Epoch time: 2068m 13s
# test Loss: nan, Acc: 0.6273
# Epoch time: 2070m 47s
# => Checkpoint at 84 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 85/100
# ---------------
# Epoch time: 2089m 12s
# Epoch time: 2091m 45s
#
# Epoch 86/100
# ---------------
# train Loss: 0.7712, Acc: 0.7183
# Epoch time: 2110m 9s
# test Loss: nan, Acc: 0.6216
# Epoch time: 2112m 43s
# => Checkpoint at 86 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 87/100
# ---------------
# Epoch time: 2131m 7s
# Epoch time: 2133m 41s
#
# Epoch 88/100
# ---------------
# train Loss: 0.7685, Acc: 0.7193
# Epoch time: 2152m 5s
# test Loss: nan, Acc: 0.6242
# Epoch time: 2154m 39s
# => Checkpoint at 88 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 89/100
# ---------------
# Epoch time: 2173m 3s
# Epoch time: 2175m 37s
#
# Epoch 90/100
# ---------------
# train Loss: 0.7637, Acc: 0.7207
# Epoch time: 2194m 1s
# test Loss: nan, Acc: 0.6228
# Epoch time: 2196m 35s
# => Checkpoint at 90 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 91/100
# ---------------
# Epoch time: 2214m 60s
# Epoch time: 2217m 33s
#
# Epoch 92/100
# ---------------
# train Loss: 0.7601, Acc: 0.7224
# Epoch time: 2235m 57s
# test Loss: nan, Acc: 0.6293
# Epoch time: 2238m 31s
# => Checkpoint at 92 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 93/100
# ---------------
# Epoch time: 2256m 56s
# Epoch time: 2259m 30s
#
# Epoch 94/100
# ---------------
# train Loss: 0.7612, Acc: 0.7224
# Epoch time: 2277m 54s
# test Loss: nan, Acc: 0.6269
# Epoch time: 2280m 28s
# => Checkpoint at 94 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 95/100
# ---------------
# Epoch time: 2298m 52s
# Epoch time: 2301m 26s
#
# Epoch 96/100
# ---------------
# train Loss: 0.7594, Acc: 0.7225
# Epoch time: 2319m 49s
# test Loss: nan, Acc: 0.6271
# Epoch time: 2322m 23s
# => Checkpoint at 96 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 97/100
# ---------------
# Epoch time: 2340m 48s
# Epoch time: 2343m 22s
#
# Epoch 98/100
# ---------------
# train Loss: 0.7678, Acc: 0.7213
# Epoch time: 2361m 45s
# test Loss: nan, Acc: 0.6242
# Epoch time: 2364m 19s
# => Checkpoint at 98 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Epoch 99/100
# ---------------
# Epoch time: 2382m 43s
# Epoch time: 2385m 17s
#
# Epoch 100/100
# ---------------
# train Loss: 0.7609, Acc: 0.7225
# Epoch time: 2403m 44s
# test Loss: nan, Acc: 0.6222
# Epoch time: 2406m 18s
# => Checkpoint at 100 saved!
# Saved at: ./checkpoints/efficientnet/efficientnetb1-0.8.pth.tar
#
# Training complete in 2406m 19s
# Trainig completed at 13:21
# Best val Acc: 0.637979
# Best sk F1 : 0.637979

# %%
# Export to CSV
for phase in ['train', 'test']:
    for metric in ['accuracy', 'loss']:
        df = pd.DataFrame(results[phase][metric])
        df.to_csv(f'D:/sl/CSV/{hyper_parameter["model"]}-{hyper_parameter["version"]}-{phase}-{metric}-{hyper_parameter["attempt"]}.csv', mode='a')

# %%
for phase in ['train', 'test']:
    csv_path = f'./CSV/{hyper_parameter["model"]}-{hyper_parameter["version"]}-{phase}-{metric}-{hyper_parameter["attempt"]}.csv'
    for metric in ['accuracy', 'loss']:
        prev_result = pd.read_csv(csv_path)

# %%
for phase in ['train', 'test']:
    plt.plot(results[phase]['accuracy'], label='{} accuracy'.format(phase))
    plt.title(f'{hyper_parameter["model"]} {hyper_parameter["version"]} learning rate: {hyper_parameter["learning_rate"]} epoch: {hyper_parameter["no_epochs"]}')
    plt.legend(bbox_to_anchor = (1.45, 1), loc='upper right')
    plt.tight_layout()
    plt.savefig(f'accuracy.jpeg')
plt.show()

for phase in ['train', 'test']:
    df_cm = pd.DataFrame(results[phase]['cf_matrix'], index = class_names, columns = class_names)
    plt.figure(figsize = (12,7))
    sn.heatmap(df_cm, annot=True)
    plt.tight_layout()
    plt.savefig(f'cf_matrix{phase}.jpeg')
plt.show()

# %% [markdown]
# # Methods to try
# https://stackoverflow.com/questions/62319228/number-of-instances-per-class-in-pytorch-dataset
